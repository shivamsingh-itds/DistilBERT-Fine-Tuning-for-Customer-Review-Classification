# %%
import pandas as pd
# Out:
# c:\Anaconda\Lib\site-packages\pandas\core\computation\expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.10.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
import pandas as pd

synthetic_df1 = pd.read_csv(
    r"C:\ResoluteAi\fineturningdestilBERT\Dataset\Synthetic1.txt",
    header=None,
    names=["review_text", "issue"],
    quotechar='"'
)

print(synthetic_df1.head())
print(synthetic_df1.shape)
# Out:
#                                          review_text             issue
# 0  The color is completely different from the onl...  Color_Appearance
# 1  After two washes, the bright blue floral patte...  Color_Appearance
# 2  The product images show a vibrant red, but wha...  Color_Appearance
# 3  The white sheets have a yellow tint that makes...  Color_Appearance
# 4  The black color bleeds everywhere. My white pi...  Color_Appearance
# (737, 2)

# %%
synthetic_df2 = pd.read_csv(
    r"C:\ResoluteAi\fineturningdestilBERT\Dataset\Synthetic2.txt",
    header=None,
    names=["review_text", "issue"],
    quotechar='"'
)

print(synthetic_df2.head())
print(synthetic_df2.shape)
# Out:
#                                          review_text          issue
# 0  I sent the item back over a month ago and I'm ...  Return_Refund
# 1  They refused to take the return because the or...  Return_Refund
# 2  The refund amount was less than what I paid, a...  Return_Refund
# 3  I requested an exchange, but they just refunde...  Return_Refund
# 4  The return shipping cost me almost as much as ...  Return_Refund
# (901, 2)

# %%
synthetic_df3 = pd.read_csv(
    r"C:\ResoluteAi\fineturningdestilBERT\Dataset\synthetic3.txt",
    header=None,
    names=["review_text", "issue"],
    quotechar='"'
)

print(synthetic_df3.head())
print(synthetic_df3.shape)
# Out:
#                                          review_text             issue
# 0  I emailed customer support over a week ago abo...  Customer_Service
# 1  The representative I spoke with on the phone w...  Customer_Service
# 2  I have an unresolved complaint that has been o...  Customer_Service
# 3  The support agents are completely unhelpful an...  Customer_Service
# 4  Dealing with their help desk was a terrible se...  Customer_Service
# (258, 2)

# %%
synthetic = pd.concat([synthetic_df1,synthetic_df2,synthetic_df3] , ignore_index= True)

# %%
synthetic
# Out:
#                                             review_text             issue
# 0     The color is completely different from the onl...  Color_Appearance
# 1     After two washes, the bright blue floral patte...  Color_Appearance
# 2     The product images show a vibrant red, but wha...  Color_Appearance
# 3     The white sheets have a yellow tint that makes...  Color_Appearance
# 4     The black color bleeds everywhere. My white pi...  Color_Appearance
# ...                                                 ...               ...
# 1891  I am highly satisfied with the incredible comf...          Positive
# 1892  The quality is superb with very neat hems, off...          Positive
# 1893  These provide wonderful comfort and remarkable...          Positive
# 1894  A solid good value that looks great and offers...          Positive
# 1895  The appearance is modern and crisp, while the ...          Positive
#
# [1896 rows x 2 columns]

# %%
synthetic.to_excel("synthetic3.xlsx" , index= False)

# %%
synthetic_df3 = pd.read_
